# %% [markdown]
# ANSWERS ARE AS FOLLOWS :-->
#
# 1. --> #this my python code
#        Hashtag is use for single line comments.
#
#        """ this my python code
#            python is a programming language """
#
#            This used is used for multi-line comments.
#
#         There are two type of comments :->
#         1. single-line.
#         2. multi-line.
#
# 2. --> Variables are mainly used for storing type of datas,that will be access in future for further use.
#        we can assign values to variable by simply using:
#        name = 'Mohil'
#        age = 20
#
# 3. --> We can simply convert one data type to other data type by using some inbuilt functions provided by python language.
#        For example :-> If we have to convert integer value to string.
#                        str(20)
#                        In this way 20 is converted to string value.
#
#                        or We convert integer 1 and 0 to boolean type by using bool() function and vice versa by using int(True) and int(False).
#
#                        We also convert float to int and vice-versa by using float() and int() functions.
#
#
# 4. --> open a command line and type the word python followed by the path to your script file like this: python first_script.py        Hello World! Then you hit the ENTER button from the keyboard, and that's it.
#
#
#
#
#
#
#
# 5. --> my_list = [1, 2, 3, 4, 5]    Required list --> [2,3]
#
#        Required code :-> my_list[1:3]
#
# 6. --> Complex numbers are used for representing real axis as well as imaginery axis.
#        It is consist of two parts :->
#        1. Real part
#        2. Imaginary Part
#
#        In python programming it will representated as -> 4+5j , 3+2j ,(We does not use any other alphabet rather than j).
#
# 7. --> age = 25
#
# 8. --> price = 9.99
#        type(price) = float.
#
# 9. --> name = 'Mohil Dubey'
#        For printing we have two ways :->
#        1. simply call variable name.
#        2. print(name).
#
# 10. --> string = "Hello, World!"
#         Code :-->  string[7:12]
#
# 11. --> is_student = True
